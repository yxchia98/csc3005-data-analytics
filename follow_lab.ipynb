# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd

meter_a_df = pd.read_csv('dataset/Meter A',header=None, sep="\t")
meter_a_df.columns = ['Flatness Ratio',
                      'Symmetry',
                      'Crossflow',
                      'Flow Velocity 1',
                      'Flow Velocity 2',
                      'Flow Velocity 3',
                      'Flow Velocity 4',
                      'Flow Velocity 5',
                      'Flow Velocity 6',
                      'Flow Velocity 7',
                      'Flow Velocity 8',
                      'Speed of Sound 1',
                      'Speed of Sound 2',
                      'Speed of Sound 3',
                      'Speed of Sound 4',
                      'Speed of Sound 5',
                      'Speed of Sound 6',
                      'Speed of Sound 7',
                      'Speed of Sound 8',
                      'Average Speed of Sound',
                      'Gain at both ends 1',
                      'Gain at both ends 2',
                      'Gain at both ends 3',
                      'Gain at both ends 4',
                      'Gain at both ends 5',
                      'Gain at both ends 6',
                      'Gain at both ends 7',
                      'Gain at both ends 8',
                      'Gain at both ends 9',
                      'Gain at both ends 10',
                      'Gain at both ends 11',
                      'Gain at both ends 12',
                      'Gain at both ends 13',
                      'Gain at both ends 14',
                      'Gain at both ends 15',
                      'Gain at both ends 16',
                      'Class Attribute/Health State']
# Out:
#           0         1         2         3          4          5         6   \
# 0   0.841499  1.009367  0.993816  8.469805  10.278727  10.037759  8.501365
# 1   0.842250  1.006584  0.996605  7.531891   9.139924   8.951618  7.612213
# 2   0.840723  1.011647  0.998152  6.641699   7.975464   7.857692  6.593117
# 3   0.841119  1.017807  0.996812  5.687524   6.824334   6.689885  5.615428
# 4   0.840358  1.016534  0.996221  5.660385   6.829560   6.675628  5.623977
# ..       ...       ...       ...       ...        ...        ...       ...
# 82  0.792929  1.006295  0.999666  2.696691   3.414048   3.389731  2.699618
# 83  0.792309  1.004472  0.999873  2.679006   3.433638   3.386612  2.714345
# 84  0.793471  1.009560  1.001110  2.691553   3.431745   3.364790  2.717383
# 85  0.796730  1.010570  0.999029  2.714849   3.412818   3.388927  2.692776
# 86  0.790194  1.004195  0.995537  1.781262   2.247824   2.234980  1.785612
#
# ...
